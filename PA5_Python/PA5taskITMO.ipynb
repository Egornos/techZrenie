# %% [markdown]
# ## **Authors**
#
# *The work can be done in groups of up to 3 students. Please complete the following fields with your group number and list your names along with ISU ID numbers.*
#
# > **Technical Vision**
# >
# > 1. Кормушкина Ксения, 466278
# > 2. Носуленко Егор, 466921
#
# *The task and guidelines were prepared by Andrei Zhdanov and Sergei Shavetov, ITMO University, 2025.*

# %% [markdown]
# # **Practical Assignment No 5. Hough Transform**
#
# ***Study of the Hough transform to find geometric primitives.***
#
# ***Изучение преобразования Хафа для поиска геометрических примитивов.***

# %% [markdown]
# To implement the current practical assignment task we would need OpenCV, scikit-image and NumPy libraries along with image display functions we wrote during the Image Processing class. We import OpenCV's `cv2` library as `cv` for easier use.
#
# Для выполнения текущего практического задания нам понадобятся библиотеки OpenCV, scikit-image и NumPy, а также функции отображения изображений, которые мы написали во время занятий по обработке изображений. Мы импортируем библиотеку OpenCV `cv2` как `cv` для удобства использования.

# %%
# Import OpenCV library as both cv2 and cv
import cv2 as cv
# Import NumPy library as np
import numpy as np
# Import math for, yes we just need math 
import math
# Import scikit-image transform library for Hough transformation
import skimage.transform
# Import functions from our utility library
from pa_utils import ShowImages, exit

# %% [markdown]
# # **Introduction**
#
# In the current practical assignment, we will learn some basic object detection methods that allow searching for objects on an image using the common locus method.
#
# # **Введение**
#
# В текущем практическом задании мы изучим некоторые базовые методы обнаружения объектов, которые позволяют искать объекты на изображении, используя метод общего геометрического места точек.

# %% [markdown]
# ## Common Locus of Points
#
# The main principle of the Hough transform [1] is to find a common *locus of points*. For example, this approach is used when designing a triangle along three given sides. At first one side of the triangle is laid off, after that the ends of the segment are considered as the centers of circles with radii equal to the lengths of the second and third segments. The intersection of the two circles is the common locus of points, from where the segments are drawn to the ends of the first segment. In other words, a *voting* of two points was held in favor of the probable location of the third vertex of the triangle. As a result of *voting* the *winner* was the point that got two *votes* (the points on the circles got one vote each, and outside them, they got zero), see Fig. 1.
#
# [1]: Hough, P. V. C. (1962, December 18). Method and means for recognizing complex patterns (U.S. Patent No. 3,069,654). Google Patents.
#
# ## Общее геометрическое место точек
#
# Основной принцип преобразования Хафа [1] заключается в нахождении общего *геометрического места точек*. Например, этот подход используется при построении треугольника по трём заданным сторонам. Сначала откладывается одна сторона треугольника, после чего концы отрезка рассматриваются как центры окружностей с радиусами, равными длинам второй и третьей сторон. Пересечение двух окружностей является общим геометрическим местом точек, из которого проводятся отрезки к концам первого отрезка. Другими словами, проводится *голосование* двух точек в пользу вероятного местоположения третьей вершины треугольника. В результате *голосования* *победителем* становится точка, получившая два *голоса* (точки на окружностях получили по одному голосу, а вне их — ноль), см. Рис. 1.
#
# [1]: Hough, P. V. C. (1962, December 18). Method and means for recognizing complex patterns (U.S. Patent No. 3,069,654). Google Patents.
#
# | ![Finding a triangle by given three sides](images/pa2_fig1.png "Finding a triangle by given three sides") |
# |:--:|
# | ***Fig. 1.*** *Finding a triangle by the given three sides.* |
# | ***Рис. 1.*** *Построение треугольника по трём заданным сторонам.* |
#
# Let's generalize this idea for working with real data when the image has a large number of special feature points participating in the vote. Let us assume that it is necessary to search a circle of known radius $R$ in a binary point set, and in this set, there may also be false points that do not lie on the desired circle. The set of possible circle centers for the desired radius around each characteristic point forms a circle of radius $R$, see Fig. 2 below. Thus, the point corresponding to the maximum intersection of the number of circles will be the center of the required radius circle.
#
# Давайте обобщим эту идею для работы с реальными данными, когда на изображении имеется большое количество особых точек, участвующих в голосовании. Предположим, что необходимо найти окружность известного радиуса $R$ в бинарном наборе точек, и в этом наборе также могут быть ложные точки, не лежащие на искомой окружности. Множество возможных центров окружностей для искомого радиуса вокруг каждой характерной точки образует окружность радиуса $R$, см. Рис. 2 ниже. Таким образом, точка, соответствующая максимальному пересечению количества окружностей, будет центром искомой окружности.
#
# | ![Searching a circle of known radius in a point set](images/pa2_fig2.png "Searching a circle of known radius in a point set") |
# |:--:|
# | ***Fig. 2.*** *Searching a circle of known radius in a point set.* |
# | ***Рис. 2.*** *Поиск окружности известного радиуса в наборе точек.* |

# %% [markdown]
# ## Classic Hough Transform
#
# The classic Hough transform is based on the considered point voting idea. It was originally designed to select lines on binary images. The Hough transform uses the parameter space to search for geometric primitives. The most well-known parametric equation of lines is:
#
# ## Классическое преобразование Хафа
#
# Классическое преобразование Хафа основано на рассмотренной идее голосования точек. Изначально оно было разработано для выделения линий на бинарных изображениях. Преобразование Хафа использует пространство параметров для поиска геометрических примитивов. Наиболее известное параметрическое уравнение прямых:
#
# $$
# 	y=kx+b,
# $$
#
# This equation has a problem as it can not be used to define lines that are parallel to the $Ox$ axis, so the Hough transform uses another common parametric equation of a line by a point and an inclination angle:
#
# Это уравнение имеет проблему, так как его нельзя использовать для определения прямых, параллельных оси $Ox$, поэтому преобразование Хафа использует другое распространённое параметрическое уравнение прямой через точку и угол наклона:
#
# $$
# 	x\cos{\Theta}+y\sin{\Theta}=\rho,
# $$
#
# where
# - $\rho$ is the radius vector drawn from the origin to the line;
# - $\Theta$ is the inclination angle of the radius vector.
#
# Let the straight line in the Cartesian coordinate system be given by the given equation, from which it is easy to calculate the radius vector $\rho$ and angle $\Theta$. Then we can define the Hough parameter space with coordinated $\rho$ and $\Theta$. As a result, each line of the source Cartesian space will be represented by a single point with coordinates $(\rho_0,\Theta_0)$ in the Hough parameter space, see Fig. 3.
#
# где
# - $\rho$ — радиус-вектор, проведённый из начала координат к прямой;
# - $\Theta$ — угол наклона радиус-вектора.
#
# Пусть прямая в декартовой системе координат задана данным уравнением, из которого легко вычислить радиус-вектор $\rho$ и угол $\Theta$. Тогда мы можем определить пространство параметров Хафа с координатами $\rho$ и $\Theta$. В результате каждая прямая исходного декартова пространства будет представлена одной точкой с координатами $(\rho_0,\Theta_0)$ в пространстве параметров Хафа, см. Рис. 3.
#
# | ![Representation of a straight line in Hough space](images/pa2_fig3.png "Representation of a straight line in Hough space") |
# |:--:|
# | ***Fig. 3.*** *Representation of a straight line in Hough space.* |
# | ***Рис. 3.*** *Представление прямой в пространстве Хафа.* |
#
# During the Hough transform all lines that pass via points in the source Cartesian space are converted to points in the Hough parameter space and *vote* for corresponding lines. As a result, the parameter space sums up votes given for various lines. In general, the parameter space is continuous, however, in a digital form, it is stored as a matrix. Therefore, in the Hough transform the Hough space is called *accumulator* and is a matrix $A(\rho,\Theta)$ that stores voting information.
#
# An infinite number of straight lines can be drawn passing through any of the points in the source Cartesian coordinate space and they will generate a sinusoidal response function in the parameter space. Thus, any two sinusoidal response functions in the parameter space will intersect at the point $(\rho,\Theta)$ only if the points originating them in the source Cartesian space lie on a single straight line, see Fig. 4. Based on this, we can conclude that to find straight lines in the source space, it is necessary to find all the local maxima of the accumulator matrix.
#
# В ходе преобразования Хафа все прямые, проходящие через точки в исходном декартовом пространстве, преобразуются в точки в пространстве параметров Хафа и *голосуют* за соответствующие прямые. В результате пространство параметров суммирует голоса, отданные за различные прямые. В общем случае пространство параметров непрерывно, однако в цифровой форме оно хранится в виде матрицы. Поэтому в преобразовании Хафа пространство Хафа называется *аккумулятором* и представляет собой матрицу $A(\rho,\Theta)$, хранящую информацию о голосовании.
#
# Бесконечное количество прямых может быть проведено через любую из точек исходного декартова пространства, и они будут генерировать синусоидальную функцию отклика в пространстве параметров. Таким образом, любые две синусоидальные функции отклика в пространстве параметров пересекутся в точке $(\rho,\Theta)$ только в том случае, если породившие их точки в исходном декартовом пространстве лежат на одной прямой, см. Рис. 4. Основываясь на этом, можно сделать вывод, что для нахождения прямых в исходном пространстве необходимо найти все локальные максимумы матрицы аккумулятора.
#
# | ![Voting in the Hough parameter space](images/pa2_fig4.png "Voting in the Hough parameter space") |
# |:--:|
# | ***Fig. 4.*** *Voting in the Hough parameter space.* |
# | ***Рис. 4.*** *Голосование в пространстве параметров Хафа.* |
#
# The considered line search algorithm can be used in the same way to search for any other curve described in space by some function with a certain number of parameters $F=\left(a_1,a_2,...,a_n,x,y\right)$, which will only affect the dimension of the parameter space.
#
# Let us use the Hough transform to search for circles of a given radius $R$. It is known that a circle on a plane is described by the formula:
#
# Рассмотренный алгоритм поиска линий может быть использован таким же образом для поиска любой другой кривой, описываемой в пространстве некоторой функцией с определённым количеством параметров $F=\left(a_1,a_2,...,a_n,x,y\right)$, что повлияет только на размерность пространства параметров.
#
# Давайте используем преобразование Хафа для поиска окружностей заданного радиуса $R$. Известно, что окружность на плоскости описывается формулой:
#
# $$
# (x-x_0)^2+(y-y_0)^2=R^2
# $$
#
# The set of centers of all possible circles of radius $R$ passing through a feature point forms a circle of radius $R$ around that point. Due to this the response function in the Hough transform for finding circles is a circle of the same size centered at the voting point, see Fig. 2. Then, similarly to the previous case, it is necessary to find the local maxima of the accumulator function $A(x,y)$ in the space of parameters $(x,y)$, which will be the centers of the required circles.
#
# The Hough transform is invariant to shift, scaling, and rotation. Taking into account that under projective transformations of three-dimensional space, straight lines always go only to straight lines (in the degenerate case, to points), the Hough transform makes it possible to detect lines invariably not only to affine transformations of the plane but also to the group of projective transformations in space.
#
# Множество центров всех возможных окружностей радиуса $R$, проходящих через характерную точку, образует окружность радиуса $R$ вокруг этой точки. Вследствие этого функция отклика в преобразовании Хафа для поиска окружностей представляет собой окружность того же размера с центром в точке голосования, см. Рис. 2. Затем, аналогично предыдущему случаю, необходимо найти локальные максимумы функции аккумулятора $A(x,y)$ в пространстве параметров $(x,y)$, которые будут центрами искомых окружностей.
#
# Преобразование Хафа инвариантно к сдвигу, масштабированию и повороту. Учитывая, что при проективных преобразованиях трёхмерного пространства прямые всегда переходят только в прямые (в вырожденном случае — в точки), преобразование Хафа позволяет обнаруживать прямые инвариантно не только к аффинным преобразованиям плоскости, но и к группе проективных преобразований в пространстве.

# %% [markdown]
# # **Task 1. Search for Lines**
#
# ***Take three arbitrary images containing lines. Search for straight lines using various implementations of the Hough transform. Plot the found lines on the original image. Mark the start and end points of the lines. Determine the lengths of the shortest and longest lines, and calculate the number of lines found.***
#
# # **Задание 1. Поиск линий**
#
# ***Возьмите три произвольных изображения, содержащих линии. Найдите прямые линии, используя различные реализации преобразования Хафа. Нанесите найденные линии на исходное изображение. Отметьте начальную и конечную точки линий. Определите длины самой короткой и самой длинной линий и подсчитайте количество найденных линий.***

# %% [markdown]
# ## **1.1 Hough Transform for Lines with OpenCV**
#
# OpenCV library provides two implementations for the Hough transform algorithm for search of the straight lines:
#
# - `cv2.HoughLines(image, rho, theta, threshold) -> lines` function performs the classic Hough line transform of an `image` and searches for straight lines. The `rho` and `theta` parameters define the subdivision of Hough parameter space for the corresponding axis. The `threshold` parameter defines the threshold, i.e., the number of votes that a line should get to be added to the returned `lines` array. Each line in returned `lines` array is an infinite line which is defined by `rho` ($\rho$) and `theta` ($\Theta$) parameters.
# - `cv2.HoughLinesP(image, rho, theta, threshold, minLineLength, maxLineGap) -> lines` function performs the probabilistic Hough line transform of an `image` and searches for straight lines. The main function parameters are the same, however, two extra are added: these are `minLineLength` for a minimum line length, so no line shorter than this won't be selected, and `maxLineGap` for a maximum gap between two segments of the line to consider them to be the same line instead of two separate ones. The returned 2-dimensional `lines` array contains the start and end points of each of the found line segments as arrays of four: $[x_1, y_1, x_2, y_2]$.
#
# ## **1.1 Преобразование Хафа для линий с OpenCV**
#
# Библиотека OpenCV предоставляет две реализации алгоритма преобразования Хафа для поиска прямых линий:
#
# - Функция `cv2.HoughLines(image, rho, theta, threshold) -> lines` выполняет классическое преобразование Хафа для линий на `изображении` и ищет прямые линии. Параметры `rho` и `theta` определяют разбиение пространства параметров Хафа для соответствующих осей. Параметр `threshold` определяет порог, то есть количество голосов, которое должна получить линия, чтобы быть добавленной в возвращаемый массив `lines`. Каждая линия в возвращаемом массиве `lines` является бесконечной линией, которая определяется параметрами `rho` ($\rho$) и `theta` ($\Theta$).
# - Функция `cv2.HoughLinesP(image, rho, theta, threshold, minLineLength, maxLineGap) -> lines` выполняет вероятностное преобразование Хафа для линий на `изображении` и ищет прямые линии. Основные параметры функции те же, однако добавлены два дополнительных: `minLineLength` для минимальной длины линии (линии короче этого значения не будут выбраны) и `maxLineGap` для максимального разрыва между двумя сегментами линии, чтобы считать их одной линией вместо двух отдельных. Возвращаемый двумерный массив `lines` содержит начальные и конечные точки каждого из найденных отрезков линий в виде массивов из четырёх элементов: $[x_1, y_1, x_2, y_2]$.

# %% [markdown]
# ### **1.1.1 Classic Hough Transform for Lines with OpenCV**
#
# To execute the Hough line transform in OpenCV first have to preprocess an image to get edges by executing the Canny algorithm.
#
# ### **1.1.1 Классическое преобразование Хафа для линий с OpenCV**
#
# Для выполнения преобразования Хафа для линий в OpenCV сначала необходимо предварительно обработать изображение, чтобы получить границы с помощью алгоритма Кэнни.

# %%
# Read an image from a file in BGR
fn = "images/barcode.png"
I = cv.imread(fn, cv.IMREAD_COLOR)
if not isinstance(I, np.ndarray) or I.data == None:
  print("Error reading file \"{}\"".format(fn))
  exit()

# Preprocess with Canny algorithm
Iedge = cv.Canny(I, 50, 200, None, 3)
# Display it
ShowImages([("Source image", I), 
            ("Edges", Iedge)], 2)

# %% [markdown]
# Then run the Hough line transform to get line parameters.
#
# Затем выполните преобразование Хафа для линий, чтобы получить параметры линий.

# %%
# Find lines with Hough transform
# Distance resolution: 1 pix
# Angle resolution: 1 deg in rad
# Accumulator threshold: 100
Iclassic = cv.HoughLines(Iedge, 1, np.pi / 180, 100)

# %% [markdown]
# Finally, we can draw infinite lines by returned parameters with the help of the `cv2.line()` function.
#
# Наконец, мы можем нарисовать бесконечные линии по возвращённым параметрам с помощью функции `cv2.line()`.

# %%
# Create output images
Iclassic_out = I.copy()
Iclassic_lines = np.zeros_like(I)
h, w = I.shape[:2]
l = math.sqrt(h ** 2 + w ** 2)

# Go through all found lines and display them
if Iclassic is not None:
  for i in range(0, len(Iclassic)):
    rho = Iclassic[i][0][0]
    theta = Iclassic[i][0][1]
    a, b = math.cos(theta), math.sin(theta)
    x0, y0 = a * rho, b * rho
    pt1 = np.int32((x0 - l * b, y0 + l * a))
    pt2 = np.int32((x0 + l * b, y0 - l * a))
    cv.line(Iclassic_out, pt1, pt2, (0, 255, 0), 1, cv.LINE_AA)
    cv.line(Iclassic_lines, pt1, pt2, (0, 255, 0), 1, cv.LINE_AA)

# Display it
print("Found {} lines".format(len(Iclassic)))
ShowImages([("OpenCV lines", Iclassic_lines), 
            ("OpenCV lines highlighted", Iclassic_out)], 2)

# %% [markdown]
# ### **1.1.2 Self-work**
#
# > ***Self-work***
# >
# > Take **three** arbitrary images and execute the classic Hough transform with OpenCV. Display the found lines and print their number.
# >
# > ***Notes.***
# > 1. *You may have to change the Hough transform parameters to match your images.*
#
# ### **1.1.2 Самостоятельная работа**
#
# > ***Самостоятельная работа***
# >
# > Возьмите **три** произвольных изображения и выполните классическое преобразование Хафа с помощью OpenCV. Отобразите найденные линии и выведите их количество.
# >
# > ***Примечания.***
# > 1. *Возможно, вам потребуется изменить параметры преобразования Хафа в соответствии с вашими изображениями.*

# %%
# TODO Place your solution here

images = ["images/our_photo.png", "images/our_photo2.jpg", "images/our_photo3.jpg"]

for fn in images:
    I = cv.imread(fn, cv.IMREAD_COLOR)
    if not isinstance(I, np.ndarray) or I.data is None:
        print(f"Error reading file {fn}")
        continue
    
    Iedge = cv.Canny(I, 100, 200, None, 3)
    
    ShowImages([("Source image", I), 
                ("Edges", Iedge)], 2)

    Iclassic = cv.HoughLines(Iedge, 1, np.pi / 180, 100)

    # Create output images
    Iclassic_out = I.copy()
    Iclassic_lines = np.zeros_like(I)
    h, w = I.shape[:2]
    l = math.sqrt(h ** 2 + w ** 2)

    # Go through all found lines and display them
    if Iclassic is not None:
        for i in range(0, len(Iclassic)):
            rho = Iclassic[i][0][0]
            theta = Iclassic[i][0][1]
            a, b = math.cos(theta), math.sin(theta)
            x0, y0 = a * rho, b * rho
            pt1 = np.int32((x0 - l * b, y0 + l * a))
            pt2 = np.int32((x0 + l * b, y0 - l * a))
            cv.line(Iclassic_out, pt1, pt2, (0, 255, 0), 1, cv.LINE_AA)
            cv.line(Iclassic_lines, pt1, pt2, (0, 255, 0), 1, cv.LINE_AA)

    # Display it
    print(f"Found {len(Iclassic)} lines in {fn}")
    ShowImages([("OpenCV lines", Iclassic_lines), 
                ("OpenCV lines highlighted", Iclassic_out)], 2)
# Out:
# Found 23 lines in images/our_photo.png
# Found 22 lines in images/our_photo2.jpg
# Found 6 lines in images/our_photo3.jpg

# %% [markdown]
# ### **1.1.3 Probabilistic Hough Transform for Lines with OpenCV**
#
# The probabilistic Hough line transform is executed similarly:
#
# ### **1.1.3 Вероятностное преобразование Хафа для линий с OpenCV**
#
# Вероятностное преобразование Хафа для линий выполняется аналогично:

# %%
# Find lines with Probabilistic Hough transform
# Distance resolution: 1 pix
# Angle resolution: 1 deg in rad
# Accumulator threshold: 50
# Minimum line length: 50
# Maximum line gap: 4
Iprob = cv.HoughLinesP(Iedge, 1, np.pi / 180, 50, None, 50, 4)

# %% [markdown]
# The probabilistic Hough transform will return an array of pairs of the endpoints of the found line segments which we can use to draw them on top of the source image:
#
# Вероятностное преобразование Хафа вернёт массив пар конечных точек найденных отрезков линий, которые мы можем использовать для их рисования поверх исходного изображения:

# %%
# Create and output image
Iprob_out = I.copy()
Iprob_lines = np.zeros_like(I)

# Go through all found lines and display them
if Iprob is not None:
  min_line = max_line = Iprob[0][0]
  min_line_len = max_line_len = math.sqrt((min_line[0] - min_line[2]) ** 2 + (min_line[1] - min_line[3]) ** 2)
  for i in range(1, len(Iprob)):
    l = Iprob[i][0]
    line_len = math.sqrt((l[0] - l[2]) ** 2 + (l[1] - l[3]) ** 2)
    if line_len < min_line_len:
      min_line_len = line_len
      min_line = l
    if line_len > max_line_len:
      max_line_len = line_len
      max_line = l
    cv.line(Iprob_out, (l[0], l[1]), (l[2], l[3]), (0, 255, 0), 1, cv.LINE_AA)
    cv.line(Iprob_lines, (l[0], l[1]), (l[2], l[3]), (0, 255, 0), 1, cv.LINE_AA)
    
  # Draw min and max lines
  cv.line(Iprob_out, (min_line[0], min_line[1]), (min_line[2], min_line[3]), (0, 0, 255), 1, cv.LINE_AA)
  cv.line(Iprob_lines, (min_line[0], min_line[1]), (min_line[2], min_line[3]), (0, 0, 255), 1, cv.LINE_AA)
  cv.line(Iprob_out, (max_line[0], max_line[1]), (max_line[2], max_line[3]), (0, 0, 255), 1, cv.LINE_AA)
  cv.line(Iprob_lines, (max_line[0], max_line[1]), (max_line[2], max_line[3]), (0, 0, 255), 1, cv.LINE_AA)
  
  # Display it
  print("Found {} lines".format(len(Iprob)))
  print("The shortest found line length is {}".format(min_line_len))
  print("The shortest found line is ({}, {}) - ({}, {})".format(min_line[0], min_line[1], min_line[2], min_line[3]))
  print("The longest found line length is {}".format(max_line_len))
  print("The longest found line is ({}, {}) - ({}, {})".format(max_line[0], max_line[1], max_line[2], max_line[3]))
ShowImages([("OpenCV lines", Iprob_lines), 
            ("OpenCV lines highlighted", Iprob_out)], 2)

# %% [markdown]
# ### **1.1.4 Self-work**
#
# > ***Self-work***
# >
# > Take **three** arbitrary images and execute the probabilistic Hough transform with OpenCV. Display the found lines, print their number, and print the shortest and the longest line parameters.
# >
# > ***Notes.***
# > 1. *You may have to change the Hough transform parameters to match your images.*
#
# ### **1.1.4 Самостоятельная работа**
#
# > ***Самостоятельная работа***
# >
# > Возьмите **три** произвольных изображения и выполните вероятностное преобразование Хафа с помощью OpenCV. Отобразите найденные линии, выведите их количество и параметры самой короткой и самой длинной линий.
# >
# > ***Примечания.***
# > 1. *Возможно, вам потребуется изменить параметры преобразования Хафа в соответствии с вашими изображениями.*

# %%
# TODO Place your solution here

images = ["images/our_photo.png", "images/our_photo2.jpg", "images/our_photo3.jpg"]

for fn in images:
    I = cv.imread(fn, cv.IMREAD_COLOR)
    if I is None:
        print(f"Error reading file {fn}")
        continue
    
    Iedge = cv.Canny(I, 100, 200, apertureSize=3)
    
    Iprob = cv.HoughLinesP(Iedge, 1, np.pi / 180, 50, None, 50, 4)

    Iprob_out = I.copy()
    Iprob_lines = np.zeros_like(I)
    
    if Iprob is not None:
      min_line = max_line = Iprob[0][0]
      min_line_len = max_line_len = math.sqrt((min_line[0] - min_line[2]) ** 2 + (min_line[1] - min_line[3]) ** 2)
      for i in range(1, len(Iprob)):
        l = Iprob[i][0]
        line_len = math.sqrt((l[0] - l[2]) ** 2 + (l[1] - l[3]) ** 2)
        if line_len < min_line_len:
          min_line_len = line_len
          min_line = l
        if line_len > max_line_len:
          max_line_len = line_len
          max_line = l
        cv.line(Iprob_out, (l[0], l[1]), (l[2], l[3]), (0, 255, 0), 1, cv.LINE_AA)
        cv.line(Iprob_lines, (l[0], l[1]), (l[2], l[3]), (0, 255, 0), 1, cv.LINE_AA)
        
      cv.line(Iprob_out, (min_line[0], min_line[1]), (min_line[2], min_line[3]), (0, 0, 255), 1, cv.LINE_AA)
      cv.line(Iprob_lines, (min_line[0], min_line[1]), (min_line[2], min_line[3]), (0, 0, 255), 1, cv.LINE_AA)
      cv.line(Iprob_out, (max_line[0], max_line[1]), (max_line[2], max_line[3]), (0, 0, 255), 1, cv.LINE_AA)
      cv.line(Iprob_lines, (max_line[0], max_line[1]), (max_line[2], max_line[3]), (0, 0, 255), 1, cv.LINE_AA)
      
      # Display it
      print("Found {} lines".format(len(Iprob)))
      print("The shortest found line length is {}".format(min_line_len))
      print("The shortest found line is ({}, {}) - ({}, {})".format(min_line[0], min_line[1], min_line[2], min_line[3]))
      print("The longest found line length is {}".format(max_line_len))
      print("The longest found line is ({}, {}) - ({}, {})".format(max_line[0], max_line[1], max_line[2], max_line[3]))
    ShowImages([("OpenCV lines", Iprob_lines), 
                ("OpenCV lines highlighted", Iprob_out)], 2)
# Out:
# Found 17 lines
# The shortest found line length is 97.0
# The shortest found line is (49, 18) - (146, 18)
# The longest found line length is 147.0
# The longest found line is (148, 148) - (148, 1)
# Found 48 lines
# The shortest found line length is 50.0
# The shortest found line is (1645, 659) - (1695, 659)
# The longest found line length is 423.151273187261
# The longest found line is (1316, 300) - (1540, 659)
# Found 6 lines
# The shortest found line length is 73.10950690573696
# The shortest found line is (254, 138) - (258, 65)
# The longest found line length is 249.0
# The longest found line is (33, 371) - (282, 371)

# %% [markdown]
# ## **1.2 Hough Transform for Lines with scikit-image**
#
# Unfortunately, OpenCV does not provide the functionality to obtain the Hough accumulator matrix. However, the scikit-image library also provides functions that we can use to perform the Hough transform, and opposite to OpenCV, scikit-image executes it in several steps thus allowing us to process and display the Hough parameter space.
#
# Same as OpenCV, scikit-image provides two implementations for the Hough transform algorithm for search of the straight lines. These are classic and probabilistic approaches. The main difference between OpenCV and scikit-image libraries is that in the classic approach the Hough transform contains two steps:
# 1. Calculation of the Hough parameter space;
# 2. Search for peaks in the Hough parameter space to find lines.
#
# ## **1.2 Преобразование Хафа для линий с scikit-image**
#
# К сожалению, OpenCV не предоставляет функциональность для получения матрицы аккумулятора Хафа. Однако библиотека scikit-image также предоставляет функции, которые мы можем использовать для выполнения преобразования Хафа, и в отличие от OpenCV, scikit-image выполняет его в несколько этапов, позволяя нам обрабатывать и отображать пространство параметров Хафа.
#
# Как и OpenCV, scikit-image предоставляет две реализации алгоритма преобразования Хафа для поиска прямых линий: классический и вероятностный подходы. Основное отличие между библиотеками OpenCV и scikit-image заключается в том, что в классическом подходе преобразование Хафа содержит два этапа:
# 1. Вычисление пространства параметров Хафа;
# 2. Поиск пиков в пространстве параметров Хафа для нахождения линий.

# %% [markdown]
# The following functions for Hough transform for lines are provided in scikit-image:
#
# - `skimage.transform.hough_line(image, thetas) -> hspace, angles, distances` function performs the classic Hough line transform of an `image` and calculates the Hough accumulator matrix (parameter space). The `thetas` parameter defines an array of $\Theta$ angles in radians to subdivide the Hough parameter space (defaults to 180 values in the range $[-\pi/2, \pi/2]$). It returns a tuple with three items, which are `hspace` with the Hough transform accumulator matrix; `angles` with the array of $\Theta$ angles in radians which define the Hough parameter space; and `distances` with the array of $\rho$ distances which define the Hough parameter space.
#
# - `skimage.transform.hough_line_peaks(hspace, angles, distances, min_distance, min_angle, threshold num_peaks) -> accum, theta, rho` function performs the search for peak values in the Hough parameter space acquired at the previous step. The input parameters list contains the data acquired from `skimage.transform.hough_line()` function with additional parameters for minimum distance and angle between two lies to consider them separate lines (`min_distance` and `min_angle` parameters, defined in the accumulator matrix dimensions), the minimum peak value `threshold` to choose (defaults to the half of the maximum `hspace` value) and the maximum number of peaks to search for (`num_peaks` parameter). It returns a tuple of three items (`accum`, `theta`, `rho`) corresponding to peak values in the Hough accumulator matrix. Each line in the returned arrays is an infinite line which is defined by a pair of `rho` ($\rho$) and `theta` ($\Theta$) parameters with the same array indices that scored the corresponding `accum` *votes*.
#
# - `skimage.transform.probabilistic_hough_line(image, threshold, line_length, line_gap, theta) -> lines` function performs the probabilistic Hough line transform of an `image` and searches for straight lines. The main function parameters are similar to the ones used in OpenCV. They are the `threshold` for the minimum required peak value, the minimum line length to consider (`line_length` parameter), the maximum gap between two segments of the same line (`line_gap` parameter), and an array `theta` of $\Theta$ angles to use during transformation.  The returned 3-dimensional `lines` array contains the start and end points of each of the found line segments as 2D arrays with four elements: $[[x_1, y_1], [x_2, y_2]]$.
#
# Следующие функции для преобразования Хафа для линий предоставляются в scikit-image:
#
# - Функция `skimage.transform.hough_line(image, thetas) -> hspace, angles, distances` выполняет классическое преобразование Хафа для линий на `изображении` и вычисляет матрицу аккумулятора Хафа (пространство параметров). Параметр `thetas` определяет массив углов $\Theta$ в радианах для разбиения пространства параметров Хафа (по умолчанию 180 значений в диапазоне $[-\pi/2, \pi/2]$). Она возвращает кортеж из трёх элементов: `hspace` — матрица аккумулятора преобразования Хафа; `angles` — массив углов $\Theta$ в радианах, определяющих пространство параметров Хафа; и `distances` — массив расстояний $\rho$, определяющих пространство параметров Хафа.
#
# - Функция `skimage.transform.hough_line_peaks(hspace, angles, distances, min_distance, min_angle, threshold num_peaks) -> accum, theta, rho` выполняет поиск пиковых значений в пространстве параметров Хафа, полученном на предыдущем шаге. Список входных параметров содержит данные, полученные от функции `skimage.transform.hough_line()`, с дополнительными параметрами для минимального расстояния и угла между двумя линиями, чтобы считать их отдельными линиями (параметры `min_distance` и `min_angle`, заданные в размерностях матрицы аккумулятора), минимальное пиковое значение `threshold` для выбора (по умолчанию половина максимального значения `hspace`) и максимальное количество пиков для поиска (параметр `num_peaks`). Она возвращает кортеж из трёх элементов (`accum`, `theta`, `rho`), соответствующих пиковым значениям в матрице аккумулятора Хафа. Каждая линия в возвращаемых массивах является бесконечной линией, которая определяется парой параметров `rho` ($\rho$) и `theta` ($\Theta$) с одинаковыми индексами массивов, набравшими соответствующие *голоса* `accum`.
#
# - Функция `skimage.transform.probabilistic_hough_line(image, threshold, line_length, line_gap, theta) -> lines` выполняет вероятностное преобразование Хафа для линий на `изображении` и ищет прямые линии. Основные параметры функции аналогичны используемым в OpenCV. Это `threshold` для минимального требуемого пикового значения, минимальная длина линии для рассмотрения (параметр `line_length`), максимальный разрыв между двумя сегментами одной линии (параметр `line_gap`) и массив `theta` углов $\Theta$ для использования во время преобразования. Возвращаемый трёхмерный массив `lines` содержит начальные и конечные точки каждого из найденных отрезков линий в виде двумерных массивов с четырьмя элементами: $[[x_1, y_1], [x_2, y_2]]$.

# %% [markdown]
# ### **1.2.1 Classic Hough Transform for Lines with scikit-image**
#
# Same with the OpenCV library, to execute the Hough line transform in scikit-image first we have to preprocess an image to get edges by executing the Canny algorithm.
#
# ### **1.2.1 Классическое преобразование Хафа для линий с scikit-image**
#
# Как и в библиотеке OpenCV, для выполнения преобразования Хафа для линий в scikit-image сначала необходимо предварительно обработать изображение, чтобы получить границы с помощью алгоритма Кэнни.

# %%
# Read an image from file in BGR
fn = "images/barcode.png"
I = cv.imread(fn, cv.IMREAD_COLOR)
if not isinstance(I, np.ndarray) or I.data == None:
  print("Error reading file \"{}\"".format(fn))
  exit()

# Preprocess with Canny algorithm
Iedge = cv.Canny(I, 50, 200, None, 3)
# Display it
ShowImages([("Source image", I), 
            ("Edges", Iedge)], 2)

# %% [markdown]
# Then run the Hough line transform to get the Hough parameter space accumulator matrix. Since now we have the accumulator matrix we can display it as well to see how the parameter space is formed.
#
# Затем выполните преобразование Хафа для линий, чтобы получить матрицу аккумулятора пространства параметров Хафа. Поскольку теперь у нас есть матрица аккумулятора, мы также можем отобразить её, чтобы увидеть, как формируется пространство параметров.

# %%
# Do Hough transform
# We will use 360 angles instead of the default 180
thetas = np.linspace(-np.pi / 2, np.pi / 2, 360, endpoint = False)
Ih, angles, distances = skimage.transform.hough_line(Iedge, theta = thetas)
# Show Hough parameter space
# We will resize it to make square for a better display
ShowImages([("Parameter space", cv.resize(Ih.astype(np.float32) / np.max(Ih), (Ih.shape[1], Ih.shape[1])))])

# %% [markdown]
# Now we can search for the maxima values in the Hough parameter space.
#
# Теперь мы можем искать максимальные значения в пространстве параметров Хафа.

# %%
# Find lines with Hough transform
# Minimum distance between lines: 0
# Minimum angle between lines: 0
Iaccum, Itheta, Irho = skimage.transform.hough_line_peaks(Ih, angles, distances, min_distance = 0, min_angle = 0)

# %% [markdown]
# Finally, we can draw the infinite lines found by the scikit-image Hough transform implementation with subsequent calls to the `cv2.line()` function.
#
# Наконец, мы можем нарисовать бесконечные линии, найденные реализацией преобразования Хафа в scikit-image, с помощью последующих вызовов функции `cv2.line()`.

# %%
# Create output images
Iclassic_out = I.copy()
Iclassic_lines = np.zeros_like(I)
h, w = I.shape[:2]
l = math.sqrt(h ** 2 + w ** 2)

# Go through all found lines and display them
if Itheta is not None and Irho is not None:
  for i in range(0, len(Itheta)):
    a, b = math.cos(Itheta[i]), math.sin(Itheta[i])
    x0, y0 = a * Irho[i], b * Irho[i]
    pt1 = np.int32((x0 - l * b, y0 + l * a))
    pt2 = np.int32((x0 + l * b, y0 - l * a))
    cv.line(Iclassic_out, pt1, pt2, (0, 255, 0), 1, cv.LINE_AA)
    cv.line(Iclassic_lines, pt1, pt2, (0, 255, 0), 1, cv.LINE_AA)

# Display it
print("Found {} lines".format(len(Itheta)))
ShowImages([("scikit-image Lines", Iclassic_lines), 
            ("SkImage Lines on the source", Iclassic_out)], 2)

# %% [markdown]
# ### **1.2.2 Self-work**
#
# > ***Self-work***
# >
# > Take **three** arbitrary images and execute the classic Hough transform with the scikit-image library. Display the Hough parameter space and found lines. Print the found lines their number.
# >
# > ***Notes.***
# > 1. *You may have to change the Hough transform parameters to match your images.*
#
# ### **1.2.2 Самостоятельная работа**
#
# > ***Самостоятельная работа***
# >
# > Возьмите **три** произвольных изображения и выполните классическое преобразование Хафа с помощью библиотеки scikit-image. Отобразите пространство параметров Хафа и найденные линии. Выведите количество найденных линий.
# >
# > ***Примечания.***
# > 1. *Возможно, вам потребуется изменить параметры преобразования Хафа в соответствии с вашими изображениями.*

# %%
# TODO Place your solution here

images = ["images/our_photo.png", "images/our_photo2.jpg", "images/our_photo3.jpg"]

for fn in images:
  I = cv.imread(fn, cv.IMREAD_COLOR)
  if not isinstance(I, np.ndarray) or I.data == None:
    print("Error reading file \"{}\"".format(fn))
    exit()

  Iedge = cv.Canny(I, 100, 200, None, 3)

  ShowImages([("Source image", I), 
              ("Edges", Iedge)], 2)

  thetas = np.linspace(-np.pi / 2, np.pi / 2, 360, endpoint = False)
  Ih, angles, distances = skimage.transform.hough_line(Iedge, theta = thetas)

  ShowImages([("Parameter space", cv.resize(Ih.astype(np.float32) / np.max(Ih), (Ih.shape[1], Ih.shape[1])))])

  Iaccum, Itheta, Irho = skimage.transform.hough_line_peaks(Ih, angles, distances, min_distance = 0, min_angle = 0)

  Iclassic_out = I.copy()
  Iclassic_lines = np.zeros_like(I)
  h, w = I.shape[:2]
  l = math.sqrt(h ** 2 + w ** 2)

  if Itheta is not None and Irho is not None:
    for i in range(0, len(Itheta)):
      a, b = math.cos(Itheta[i]), math.sin(Itheta[i])
      x0, y0 = a * Irho[i], b * Irho[i]
      pt1 = np.int32((x0 - l * b, y0 + l * a))
      pt2 = np.int32((x0 + l * b, y0 - l * a))
      cv.line(Iclassic_out, pt1, pt2, (0, 255, 0), 1, cv.LINE_AA)
      cv.line(Iclassic_lines, pt1, pt2, (0, 255, 0), 1, cv.LINE_AA)

  # Display it
  print("Found {} lines".format(len(Itheta)))
  ShowImages([("scikit-image Lines", Iclassic_lines), 
              ("SkImage Lines on the source", Iclassic_out)], 2)
# Out:
# Found 12 lines
# Found 2 lines
# Found 7 lines

# %% [markdown]
# ### **1.2.3 Probabilistic Hough Transform for Lines with scikit-image**
#
# The probabilistic Hough line transform with scikit-image is executed in a way similar to OpenCV. The only two differences are that now you have to use the `skimage.transform.probabilistic_hough_line(image, threshold, line_length, line_gap, theta) -> lines` function and returned lines parameters ara in 3D array instead of 2D array in OpenCV. So, the line length calculation will be as follows:
# ```python
# line = lines[i]
# line_len = math.sqrt((line[0][0] - line[1][0]) ** 2 + (line[0][1] - line[1][1]) ** 2)
# ```
#
# And the line drawing will be as follows:
# ```python
# color = (0, 0, 255) # Color in OpenCV is defined in BGR, so this will be the Red color
# cv.line(Iout, lines[i][0], lines[i][1], color, 1, cv.LINE_AA)
# ```
#
# ### **1.2.3 Вероятностное преобразование Хафа для линий с scikit-image**
#
# Вероятностное преобразование Хафа для линий с scikit-image выполняется аналогично OpenCV. Единственные два отличия заключаются в том, что теперь нужно использовать функцию `skimage.transform.probabilistic_hough_line(image, threshold, line_length, line_gap, theta) -> lines`, а возвращаемые параметры линий находятся в трёхмерном массиве вместо двумерного в OpenCV. Таким образом, вычисление длины линии будет выглядеть следующим образом:
# ```python
# line = lines[i]
# line_len = math.sqrt((line[0][0] - line[1][0]) ** 2 + (line[0][1] - line[1][1]) ** 2)
# ```
#
# А рисование линии будет выглядеть так:
# ```python
# color = (0, 0, 255) # Цвет в OpenCV определяется в BGR, поэтому это будет красный цвет
# cv.line(Iout, lines[i][0], lines[i][1], color, 1, cv.LINE_AA)
# ```

# %% [markdown]
# ### **1.2.4 Self-work**
#
# > ***Self-work***
# >
# > Take **three** arbitrary images and execute the probabilistic Hough transform with the scikit-image library. Display the found lines, print their number, and print the shortest and the longest line parameters.
# >
# > ***Notes.***
# > 1. *You may have to change the Hough transform parameters to match your images.*
#
# ### **1.2.4 Самостоятельная работа**
#
# > ***Самостоятельная работа***
# >
# > Возьмите **три** произвольных изображения и выполните вероятностное преобразование Хафа с помощью библиотеки scikit-image. Отобразите найденные линии, выведите их количество и параметры самой короткой и самой длинной линий.
# >
# > ***Примечания.***
# > 1. *Возможно, вам потребуется изменить параметры преобразования Хафа в соответствии с вашими изображениями.*

# %%
# TODO Place your solution here

images = ["images/our_photo.png", "images/our_photo2.jpg", "images/our_photo3.jpg"]

for fn in images:
    I = cv.imread(fn, cv.IMREAD_COLOR)
    if I is None:
        print(f"Error reading file {fn}")
        continue
    
    Iedge = cv.Canny(I, 100, 200, apertureSize=3)
    
    thetas = np.linspace(-np.pi / 2, np.pi / 2, 360, endpoint = False)
    Iprob = skimage.transform.probabilistic_hough_line(Iedge, threshold=50, line_length=50, line_gap=4, theta = thetas)

    Iprob_out = I.copy()
    Iprob_lines = np.zeros_like(I)
    
    if Iprob is not None:
      min_line = max_line = Iprob[0]
      min_line_len = max_line_len = math.sqrt((min_line[0][0] - min_line[1][0]) ** 2 + (min_line[0][1] - min_line[1][1]) ** 2)
      for i in range(1, len(Iprob)):
        l = Iprob[i]
        line_len = math.sqrt((l[0][0] - l[1][0]) ** 2 + (l[0][1] - l[1][1]) ** 2)
        if line_len < min_line_len:
          min_line_len = line_len
          min_line = l
        if line_len > max_line_len:
          max_line_len = line_len
          max_line = l
        cv.line(Iprob_out, l[0], l[1], (0, 255, 0), 1, cv.LINE_AA)
        cv.line(Iprob_lines, l[0], l[1], (0, 255, 0), 1, cv.LINE_AA)
        
      cv.line(Iprob_out, min_line[0], min_line[1], (0, 0, 255), 1, cv.LINE_AA)
      cv.line(Iprob_lines, min_line[0], min_line[1], (0, 0, 255), 1, cv.LINE_AA)
      cv.line(Iprob_out, max_line[0], max_line[1], (0, 0, 255), 1, cv.LINE_AA)
      cv.line(Iprob_lines, max_line[0], max_line[1], (0, 0, 255), 1, cv.LINE_AA)
      
      # Display it
      print("Found {} lines".format(len(Iprob)))
      print("The shortest found line length is {}".format(min_line_len))
      print("The shortest found line is ({}, {}) - ({}, {})".format(min_line[0][0], min_line[1][0], min_line[0][1], min_line[1][1]))
      print("The longest found line length is {}".format(max_line_len))
      print("The longest found line is ({}, {}) - ({}, {})".format(max_line[0][0], max_line[1][0], max_line[0][1], max_line[1][1]))
    ShowImages([("OpenCV lines", Iprob_lines), 
                ("OpenCV lines highlighted", Iprob_out)], 2)
# Out:
# Found 17 lines
# The shortest found line length is 94.0
# The shortest found line is (146, 52) - (131, 131)
# The longest found line length is 147.0
# The longest found line is (148, 1) - (133, 133)
# Found 45 lines
# The shortest found line length is 50.0
# The shortest found line is (175, 125) - (659, 659)
# The longest found line length is 451.42995026914195
# The longest found line is (1644, 1369) - (659, 301)
# Found 9 lines
# The shortest found line length is 53.009433122794285
# The shortest found line is (124, 177) - (150, 149)
# The longest found line length is 249.0
# The longest found line is (282, 33) - (371, 371)

# %% [markdown]
# # **Task 2. Search for Circles**
#
# ***Take three arbitrary images containing circles. Search for circles of a known radius range using the Hough transform. Plot the found circles on the original image and print the number of found circles.***
#
# # **Задание 2. Поиск окружностей**
#
# ***Возьмите три произвольных изображения, содержащих окружности. Найдите окружности известного диапазона радиусов с помощью преобразования Хафа. Нанесите найденные окружности на исходное изображение и выведите количество найденных окружностей.***

# %% [markdown]
# When searching for circles, the Hough parameter space becomes 3-dimensional. The third dimension here is added for the circle radius. Since the circle radius can be of an infinite range, it is required to define this range when executing the Hough transform operations to create the correct accumulator space 3D matrix.
#
# При поиске окружностей пространство параметров Хафа становится трёхмерным. Третье измерение здесь добавляется для радиуса окружности. Поскольку радиус окружности может быть бесконечного диапазона, необходимо определить этот диапазон при выполнении операций преобразования Хафа для создания правильной трёхмерной матрицы пространства аккумулятора.

# %% [markdown]
# ## **2.1 Hough Transform for Circles with OpenCV**
#
# The search for circles with OpenCV is rather straightforward. You don't need to do any image preprocessing as the Canny algorithm is built into a Hough transform implementation. To run Hough transform for circles with OpenCV you have to use the following function:
#
# - `cv.HoughCircles(image, method, dp, minDist, param1, param2, minRadius, maxRadius) -> circles` function is used to execute the Hough transform for Circles on a **grayscale** `image`. It returns a 2-dimensional array of circles where each circle has three parameters: $(x_0, y_0, R)$ - for the center of the circle and its radius. The Hough transform for circles is parameterized in the following way:
#     - `method` parameter defines one of two possible methods for this transformation, it can be either `cv2.HOUGH_GRADIENT` or `cv2.HOUGH_GRADIENT_ALT`. These methods are almost similar, however the second one should give a bit better accuracy.
#     - `dp` parameter defines the scale ratio of the accumulator matrix. The resolution of the accumulator matrix is `dp` times smaller than the resolution of the source image. In most cases, $1.5$ would fit well.
#     - `minDist` parameter defines the minimum distance between circle centers to be detected.
#     - `param1` is a high threshold that is passed to the Canny edge detector, while the low threshold would be equal to half of `param1`.
#     - `param2` parameter defines the threshold for the circle detection. In the case of the `cv2.HOUGH_GRADIENT` method, it is the accumulator matrix value, while for the `cv2.HOUGH_GRADIENT_ALT` method it is the circle quality measure defined in $[0, 1]$ range where $1$ is a perfect circle.
#     - `minRadius` and `maxRadius` parameters define the circle radius search range. This will define the third dimension of the Hough parameter space accumulator matrix range.
#
# ## **2.1 Преобразование Хафа для окружностей с OpenCV**
#
# Поиск окружностей с помощью OpenCV довольно прост. Вам не нужно выполнять какую-либо предварительную обработку изображения, поскольку алгоритм Кэнни встроен в реализацию преобразования Хафа. Для выполнения преобразования Хафа для окружностей с OpenCV необходимо использовать следующую функцию:
#
# - Функция `cv.HoughCircles(image, method, dp, minDist, param1, param2, minRadius, maxRadius) -> circles` используется для выполнения преобразования Хафа для окружностей на **полутоновом** `изображении`. Она возвращает двумерный массив окружностей, где каждая окружность имеет три параметра: $(x_0, y_0, R)$ — центр окружности и её радиус. Преобразование Хафа для окружностей параметризуется следующим образом:
#     - Параметр `method` определяет один из двух возможных методов для этого преобразования: `cv2.HOUGH_GRADIENT` или `cv2.HOUGH_GRADIENT_ALT`. Эти методы почти аналогичны, однако второй должен давать немного лучшую точность.
#     - Параметр `dp` определяет коэффициент масштабирования матрицы аккумулятора. Разрешение матрицы аккумулятора в `dp` раз меньше разрешения исходного изображения. В большинстве случаев подходит значение $1.5$.
#     - Параметр `minDist` определяет минимальное расстояние между центрами обнаруживаемых окружностей.
#     - `param1` — это высокий порог, передаваемый детектору границ Кэнни, в то время как низкий порог будет равен половине `param1`.
#     - Параметр `param2` определяет порог для обнаружения окружностей. В случае метода `cv2.HOUGH_GRADIENT` это значение матрицы аккумулятора, а для метода `cv2.HOUGH_GRADIENT_ALT` — это мера качества окружности, определённая в диапазоне $[0, 1]$, где $1$ — идеальная окружность.
#     - Параметры `minRadius` и `maxRadius` определяют диапазон поиска радиуса окружности. Это определит третье измерение диапазона матрицы аккумулятора пространства параметров Хафа.

# %% [markdown]
# To display the found circles the `cv2.circle(image, center, radius, color, thickness, lineType)` function may be used to draw a circle on the `image` with the given `center` point, `radius`, and `thickness`. The $lineType$ parameter is used to define the type of the line, which can be set to `cv2.LINE_AA` for an antialiased line.
#
# For example, drawing a circle on an image `Iout` with center $(50,  50)$ and radius $10$ and thickness $1$ with blue color would be written as follows:
#
# ```python
# cv2.circle(Iout, (50, 50), 10, (255, 0, 0), 1)
# ```
#
# Для отображения найденных окружностей можно использовать функцию `cv2.circle(image, center, radius, color, thickness, lineType)`, чтобы нарисовать окружность на `изображении` с заданными центром `center`, радиусом `radius` и толщиной `thickness`. Параметр `lineType` используется для определения типа линии, который может быть установлен в `cv2.LINE_AA` для сглаженной линии.
#
# Например, рисование окружности на изображении `Iout` с центром $(50, 50)$, радиусом $10$ и толщиной $1$ синим цветом будет выглядеть следующим образом:
#
# ```python
# cv2.circle(Iout, (50, 50), 10, (255, 0, 0), 1)
# ```

# %% [markdown]
# ### **2.1.1 Self-work**
#
# > ***Self-work***
# >
# > Implement the search for circles with the Hough transform and OpenCV.
# >
# > Take **three** arbitrary images and execute the Hough transform for circles with OpenCV. Display the found circles, and print their number.
# >
# > ***Note.*** *You may have to change the Hough transform parameters to match your images.*
#
# ### **2.1.1 Самостоятельная работа**
#
# > ***Самостоятельная работа***
# >
# > Реализуйте поиск окружностей с помощью преобразования Хафа и OpenCV.
# >
# > Возьмите **три** произвольных изображения и выполните преобразование Хафа для окружностей с помощью OpenCV. Отобразите найденные окружности и выведите их количество.
# >
# > ***Примечание.*** *Возможно, вам потребуется изменить параметры преобразования Хафа в соответствии с вашими изображениями.*

# %%
# TODO Place your solution here
def find_and_draw_circles(image_path):
    img = cv.imread(image_path)
    if img is None:
        print(f"Ошибка: не удалось загрузить {image_path}")
        return
    
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    
    circles = cv.HoughCircles(
        gray,
        cv.HOUGH_GRADIENT_ALT,
        dp=1.5,
        minDist=40,
        param1=150,
        param2=0.7,
        minRadius=10,
        maxRadius=70
    )
    
    result = img.copy()
    
    if circles is not None:
        circles = np.uint16(np.around(circles))
        for (x, y, r) in circles[0, :]:
            cv.circle(result, (x, y), r, (0, 255, 0), 2)
            cv.circle(result, (x, y), 2, (0, 0, 255), 3)
        print(f"Найдено окружностей: {len(circles[0])}")
    else:
        print("Окружности не найдены")
    
    ShowImages([("Исходник", img), ("Результат", result)], 2)

find_and_draw_circles("images/circles_1.jpg")
find_and_draw_circles("images/circles_2.jpg")
find_and_draw_circles("images/circles_3.jpg")
# Out:
# Найдено окружностей: 6
# Найдено окружностей: 14
# Найдено окружностей: 39

# %% [markdown]
# ## **2.2 Hough Transform for Circles with scikit-image**
#
# When implementing the Hough transform for circles with scikit-image library you have to do the same two steps as you did for lines. These are:
# 1. Calculation of the Hough parameter space;
# 2. Search for peaks in the Hough parameter space to find circles.
#
# Since the Hough transform is split into two steps it means that with scikit-image we can check the Hough parameter space as well.
#
# ## **2.2 Преобразование Хафа для окружностей с scikit-image**
#
# При реализации преобразования Хафа для окружностей с помощью библиотеки scikit-image необходимо выполнить те же два шага, что и для линий:
# 1. Вычисление пространства параметров Хафа;
# 2. Поиск пиков в пространстве параметров Хафа для нахождения окружностей.
#
# Поскольку преобразование Хафа разделено на два этапа, это означает, что с помощью scikit-image мы также можем проверить пространство параметров Хафа.

# %% [markdown]
# The following functions for Hough transform for lines are provided in scikit-image:
#
# - `skimage.transform.hough_circle(image, radius, normalize, full_output) -> hspaces` function performs the Hough circle transform of an `image` and calculates the 3-dimensional Hough accumulator matrix. The `radius` parameter is either a scalar to search for a single radius or an array of radii. Two optional parameters allow to `normalize` the output accumulator spaces by the number of pixels required to draw a circle to make different radii circles to have the same weight in the accumulator (*True* by default) and to increase the size of the accumulator by two maximum radii to be able to get `full_output` and find circles with centers at outside of the image (*False* by default). It returns a 3D accumulator Hough parameter space matrix (an array of 2D Hough parameter spaces for each of the radii from the `radius` list).
#
# - `skimage.transform.hough_circle_peaks(hspaces, radii, min_xdistance, min_ydistance, threshold, num_peaks, total_num_peaks, normalize) -> accum, cx, cy, rad` function performs the search for peak values in the 3D Hough parameter space `hspaces` acquired at the previous step with an array of `radii`. Optional parameters allow specifying the minimum distances between picked circle centers (`min_xdistance` along $Ox$ and `min_ydistance` along $Oy$), the `threshold` parameter for peaks (half of the maximum `hspaces` value by default), the maximum number of peaks selected in a single layer Hough parameter space and all spaces total (`num_peaks` and `total_num_peaks` parameters correspondingly). Also, it's possible to `normalize` peaks by the radius as otherwise the peaks of the higher radius would be preferred over the the smaller radius (default behavior).
#
# It should be noted that scikit-image also provides a function for the Hough transform for ellipses which is out of the current practical assignment scope. If you are interested, you may try it as well. The arguments are similar to the one used for circles, however, it also allows searching for ellipses with the specified parameters range and returns an array of tuples with found ellipses: `skimage.transform.hough_ellipse(image, threshold = 4, accuracy = 1, min_size = 4, max_size = None) -> [(accumulator, yc, xc, a, b, orientation)]`
#
# Следующие функции для преобразования Хафа для окружностей предоставляются в scikit-image:
#
# - Функция `skimage.transform.hough_circle(image, radius, normalize, full_output) -> hspaces` выполняет преобразование Хафа для окружностей на `изображении` и вычисляет трёхмерную матрицу аккумулятора Хафа. Параметр `radius` может быть либо скаляром для поиска одного радиуса, либо массивом радиусов. Два необязательных параметра позволяют `normalize` (нормализовать) выходные пространства аккумулятора на количество пикселей, необходимое для рисования окружности, чтобы окружности разных радиусов имели одинаковый вес в аккумуляторе (*True* по умолчанию), и увеличить размер аккумулятора на два максимальных радиуса, чтобы иметь возможность получить `full_output` (полный вывод) и находить окружности с центрами за пределами изображения (*False* по умолчанию). Она возвращает трёхмерную матрицу пространства параметров аккумулятора Хафа (массив двумерных пространств параметров Хафа для каждого радиуса из списка `radius`).
#
# - Функция `skimage.transform.hough_circle_peaks(hspaces, radii, min_xdistance, min_ydistance, threshold, num_peaks, total_num_peaks, normalize) -> accum, cx, cy, rad` выполняет поиск пиковых значений в трёхмерном пространстве параметров Хафа `hspaces`, полученном на предыдущем шаге, с массивом `radii`. Необязательные параметры позволяют указать минимальные расстояния между выбранными центрами окружностей (`min_xdistance` по оси $Ox$ и `min_ydistance` по оси $Oy$), параметр `threshold` для пиков (по умолчанию половина максимального значения `hspaces`), максимальное количество пиков, выбираемых в одном слое пространства параметров Хафа и во всех пространствах в сумме (параметры `num_peaks` и `total_num_peaks` соответственно). Также можно `normalize` (нормализовать) пики по радиусу, так как в противном случае пики большего радиуса будут иметь преимущество перед пиками меньшего радиуса (поведение по умолчанию).
#
# Следует отметить, что scikit-image также предоставляет функцию для преобразования Хафа для эллипсов, которая выходит за рамки текущего практического задания. Если вам интересно, вы также можете попробовать её. Аргументы аналогичны используемым для окружностей, однако она также позволяет искать эллипсы с указанным диапазоном параметров и возвращает массив кортежей с найденными эллипсами: `skimage.transform.hough_ellipse(image, threshold = 4, accuracy = 1, min_size = 4, max_size = None) -> [(accumulator, yc, xc, a, b, orientation)]`

# %% [markdown]
# Let us take an image with coins and try finding them by the Hough transform. Since scikit-image libraries work with black-and-white images, we have to preprocess it with Canny algorithm to find edges first.
#
# Давайте возьмём изображение с монетами и попробуем найти их с помощью преобразования Хафа. Поскольку библиотеки scikit-image работают с черно-белыми изображениями, мы должны сначала предварительно обработать его с помощью алгоритма Кэнни, чтобы найти границы.

# %%
# Read an image from file in BGR
fn = "images/coins.jpg"
I2 = cv.imread(fn, cv.IMREAD_COLOR)
if not isinstance(I2, np.ndarray) or I2.data == None:
  print("Error reading file \"{}\"".format(fn))
  exit()

# Preprocess with Canny algorithm
I2edge = cv.Canny(I2, 200, 250)
# Display it
ShowImages([("Source image", I2), 
            ("Edges", I2edge)], 2)

# %% [markdown]
# Now we can run the Hough circles transform. Since we know that we are searching for circles in the range from $40$ to $60$ pixels, so we will define it as our radii range with step $5$.
#
# Теперь мы можем выполнить преобразование Хафа для окружностей. Поскольку мы знаем, что ищем окружности в диапазоне от $40$ до $60$ пикселей, мы определим это как наш диапазон радиусов с шагом $5$.

# %%
# Find circles with Hough transform
# Detect circles with radii in range from 40 to 60 with step 5
radii = np.arange(40, 61, 5)
I2h = skimage.transform.hough_circle(I2edge, radii)

# Show Hough parameter space
# We will resize it to make square for a better display
spaces = []
for i in range(len(radii)):
  spaces.append(("Radius {}".format(radii[i]), cv.resize(I2h[i].astype(np.float32) / np.max(I2h[i]), (I2h[i].shape[1], I2h[i].shape[1]))))
ShowImages(spaces, 3)

# %% [markdown]
# Now we can search for maxima values in the Hough parameter spaces and draw the found circles with subsequent calls to the `cv2.circle()` function.
#
# Теперь мы можем искать максимальные значения в пространствах параметров Хафа и рисовать найденные окружности с помощью последующих вызовов функции `cv2.circle()`.

# %%
# Select the most prominent 10 circles
# Minimum distance between centers along X: 30
# Minimum distance between centers along Y: 30
I2accum, I2cx, I2cy, I2radii = skimage.transform.hough_circle_peaks(I2h, radii, 45, 45)#, total_num_peaks = 14)

# Create output images
I2out = I2.copy()
I2circles = np.zeros_like(I2)

# Go through all found circles and display them
if I2cx is not None and I2cy is not None and I2radii is not None:
  for i in range(0, len(I2cx)):
    center = np.int32((I2cx[i], I2cy[i]))
    radius = int(I2radii[i])
    cv.circle(I2out, center, 1, (0, 255, 0), 1)
    cv.circle(I2out, center, radius, (0, 255, 0), 1)
    cv.circle(I2circles, center, 1, (0, 255, 0), 1)
    cv.circle(I2circles, center, radius, (0, 255, 0), 1)

# Display it
print("Found {} circles".format(len(I2cx)))
ShowImages([("scikit-image Circles", I2circles), 
            ("scikit-image Circles on the source", I2out)], 2)

# %% [markdown]
# ### **2.2.1 Self-work**
#
# > ***Self-work***
# >
# > Take **three** arbitrary images and execute the Hough transform for circles with the scikit-image library. Display the found circles and print their number.
# >
# > ***Notes.***
# > 1. *You may have to change the Hough transform parameters to match your images.*
#
# ### **2.2.1 Самостоятельная работа**
#
# > ***Самостоятельная работа***
# >
# > Возьмите **три** произвольных изображения и выполните преобразование Хафа для окружностей с помощью библиотеки scikit-image. Отобразите найденные окружности и выведите их количество.
# >
# > ***Примечания.***
# > 1. *Возможно, вам потребуется изменить параметры преобразования Хафа в соответствии с вашими изображениями.*

# %%
def find_circles_skimage(image_path, min_radius, max_radius, step=5, min_dist=45, threshold=None):
    fn = image_path
    I2 = cv.imread(fn, cv.IMREAD_COLOR)
    if not isinstance(I2, np.ndarray) or I2.data == None:
        print("Error reading file \"{}\"".format(fn))
        return None
    
    I2edge = cv.Canny(I2, 50, 150)
    
    radii = np.arange(min_radius, max_radius + 1, step)
    I2h = skimage.transform.hough_circle(I2edge, radii, normalize=True)
    
    if threshold is None:
        threshold = 0.5 * np.max(I2h)
    
    I2accum, I2cx, I2cy, I2radii = skimage.transform.hough_circle_peaks(
        I2h, radii, 
        min_xdistance=min_dist, 
        min_ydistance=min_dist,
        threshold=threshold,
        normalize=True
    )
    
    I2out = I2.copy()
    I2circles = np.zeros_like(I2)
    
    if I2cx is not None and len(I2cx) > 0:
        for i in range(0, len(I2cx)):
            center = np.int32((I2cx[i], I2cy[i]))
            radius = int(I2radii[i])
            cv.circle(I2out, center, 2, (0, 0, 255), 3)
            cv.circle(I2out, center, radius, (0, 255, 0), 2)
            cv.circle(I2circles, center, 2, (0, 0, 255), 3)
            cv.circle(I2circles, center, radius, (0, 255, 0), 2)
        
        print("Found {} circles".format(len(I2cx)))
        ShowImages([("scikit-image Circles", I2circles), 
                    ("scikit-image Circles on the source", I2out)], 2)
    else:
        print("Image {}: No circles found".format(fn))

find_circles_skimage("images/circles_1.jpg", 30, 71, 2, 10, threshold=0.5)
find_circles_skimage("images/circles_2.jpg", 10, 26, 2, 40, threshold=0.6)
find_circles_skimage("images/circles_3.jpg", 30, 61, 2, 40, threshold=0.45)
# Out:
# Found 22 circles
# Found 15 circles
# Found 14 circles

# %% [markdown]
# # **Task 3. Optional**
#
# ***Implement the classic Hough transform algorithms for lines by yourself. Compare your implementation results with the ones obtained in the first parts of the assignment. Highlight the selected points in the Hough parameter space.***
#
# # **Задание 3. Необязательное**
#
# ***Реализуйте классический алгоритм преобразования Хафа для линий самостоятельно. Сравните результаты вашей реализации с результатами, полученными в первых частях задания. Выделите выбранные точки в пространстве параметров Хафа.***

# %% [markdown]
# To implement the Hough transform for straight lines you have to allocate an accumulator matrix manually and implement the classic algorithm for the Hough transform to fill the accumulator matrix:
#
# ```python
# For each point of the source space (x,y)
#   For theta = 0 to 180
#     rho = x cos theta + y sin theta
#     H(theta, rho) = H(theta, rho) + 1
#   end
# end
# ```
#
# After the accumulator matrix is filled you should select maxima. The simplest way to do it is to use the thresholding method you learned in the previous class.
#
# ***Notes.***
# 1. *Python implementation for this algorithm would be very slow so consider taking the low-resolution input image.*
# 2. *Don't forget to run the Canny algorithm before the Hough transform to filter the edge points.*
#
# Для реализации преобразования Хафа для прямых линий вам необходимо вручную выделить матрицу аккумулятора и реализовать классический алгоритм преобразования Хафа для заполнения матрицы аккумулятора:
#
# ```python
# Для каждой точки исходного пространства (x,y)
#   Для theta от 0 до 180
#     rho = x cos theta + y sin theta
#     H(theta, rho) = H(theta, rho) + 1
#   конец
# конец
# ```
#
# После заполнения матрицы аккумулятора следует выбрать максимумы. Самый простой способ сделать это — использовать метод пороговой обработки, который вы изучали на предыдущем занятии.
#
# ***Примечания.***
# 1. *Реализация этого алгоритма на Python будет очень медленной, поэтому рассмотрите возможность использования входного изображения с низким разрешением.*
# 2. *Не забудьте запустить алгоритм Кэнни перед преобразованием Хафа для фильтрации граничных точек.*

# %% [markdown]
# > ***Self-work (optional)***
# >
# > Implement the Hough transform for straight lines. Display the result.
# >
# > ***Самостоятельная работа (необязательная)***
# >
# > Реализуйте преобразование Хафа для прямых линий. Отобразите результат.

# %%
# TODO Place your solution here

def manual_hough_lines(image_path, theta_res=180, threshold=100):
    fn = image_path
    img = cv.imread(fn, cv.IMREAD_COLOR)
    if img is None:
        print("Error reading file \"{}\"".format(image_path))
        return
    
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    edges = cv.Canny(gray, 50, 200)
    
    h, w = edges.shape
    max_rho = int(np.sqrt(h**2 + w**2))
    
    thetas = np.deg2rad(np.linspace(-90, 90, theta_res))
    
    accumulator = np.zeros((theta_res, 2 * max_rho), dtype=np.uint64)
    
    y_idxs, x_idxs = np.nonzero(edges)
    
    for i in range(len(x_idxs)):
        x = x_idxs[i]
        y = y_idxs[i]
        
        for t_idx in range(theta_res):
            theta = thetas[t_idx]
            rho = int(x * np.cos(theta) + y * np.sin(theta))
            rho_idx = rho + max_rho
            accumulator[t_idx, rho_idx] += 1
    
    lines = []
    for t_idx in range(theta_res):
        for r_idx in range(2 * max_rho):
            if accumulator[t_idx, r_idx] >= threshold:
                rho = r_idx - max_rho
                theta = thetas[t_idx]
                lines.append((rho, theta))
    
    result = img.copy()
    l = math.sqrt(h**2 + w**2)
    
    for rho, theta in lines:
        a, b = math.cos(theta), math.sin(theta)
        x0, y0 = a * rho, b * rho
        pt1 = np.int32((x0 - l * b, y0 + l * a))
        pt2 = np.int32((x0 + l * b, y0 - l * a))
        cv.line(result, pt1, pt2, (0, 255, 0), 1, cv.LINE_AA)
    
    print("Found {} lines".format(len(lines)))
    ShowImages([("Image", img), ("Manual Hough Lines", result)], 2)

manual_hough_lines("images/our_photo.png", 180, 100)
manual_hough_lines("images/our_photo2.jpg", 180, 120)
manual_hough_lines("images/our_photo3.jpg", 180, 90)
# Out:
# Found 37 lines
# Found 52 lines
# Found 12 lines

# %% [markdown]
# # **Questions**
#
# ***Please answer the following questions:***
#
# # **Вопросы**
#
# ***Пожалуйста, ответьте на следующие вопросы:***
#
#  - *What is the main principle of the Hough transform?*
#  - *В чём заключается основной принцип преобразования Хафа?*
# > Принцип голосования. Каждая точка голосует за все возможные параметры. Параметры с максимумом голосов (локальные максимумы в аккумуляторе) соответствуют искомым фигурам.
#  >
#  >
#
#  - *May the Hough transform be used to find arbitrary contours that cannot be described analytically?*
#  - *Может ли преобразование Хафа использоваться для поиска произвольных контуров, которые не могут быть описаны аналитически?*
#  > Да, с помощью обобщённого преобразования Хафа. Оно использует R-таблицу с направлением градиента и положением относительно опорной точки вместо аналитического уравнения.
#  >
#  >
#
#  - *What are the recurrent and generalized Hough transforms?*
#  - *Что такое рекуррентное и обобщённое преобразования Хафа?*
# > - **Рекуррентное**: итеративный подход – обнаружить примитив, удалить его точки, повторить. Находит перекрывающиеся объекты.
# > - **Обобщённое**: обнаруживает произвольные формы с помощью R-таблицы, кодирующей геометрию границы.
#  >
#  >
#
#  - *What are the other ways of line parametrization in the Hough transform?*
#  - *Какие существуют другие способы параметризации линии в преобразовании Хафа?*
# > 1. Форма \( y = kx + b \) (проблема с вертикальными линиями)
# > 2. Параметризация двумя точками (4D пространство)
# > 3. Нормализованная форма
# > 4. Угол направления и расстояние
# > 5. Координаты основания перпендикуляра
#  >

# %% [markdown]
# # **Conclusion**
#
# ***What have you learned with this task? Don't forget to conclude it.***
#
# # **Заключение**
#
# ***Что вы узнали, выполняя это задание? Не забудьте подвести итог.***
#
# *Задание 1*
#
# > В этом задании было реализовано преобразование Хафа для поиска прямых линий с использованием библиотек OpenCV и scikit-image. Были применены как классический, так и вероятностный варианты алгоритма.
# >
# > **Классическое преобразование Хафа (OpenCV):**
# >
# > На первом изображении алгоритм успешно обнаружил основные линии: контуры квадратов в судоку. Были найдены как вертикальные, так и горизонтальные линии, что соответствует ожидаемой геометрии. Алгоритм так же продемонстрировал устойчивость к шумам.
# >
# > На втором изображении алгоритм корректно выделил линии дорожной разметки. Вероятностная версия показала лучшие результаты, так как возвращала отрезки линий с конечными точками, а не бесконечные прямые.
# >
# >На третьем изображении были обнаружены линии дверного проема, ступеней и другие прямолинейные элементы.
# >
# > **Преобразование Хафа с scikit-image:**
# >Реализация через scikit-image позволила визуализировать пространство параметров Хафа, что дало лучшее понимание процесса голосования. На всех трёх изображениях результаты были сопоставимы с OpenCV, однако потребовалась дополнительная настройка пороговых значений для оптимального обнаружения и время, затраченное на выполнение задания, оказалось больше. А так же классическим методом удалось обнаружить меньшее количество прямых отрезков в сравнении с методом OpenCV, в то время как вероятностное преобразование показало результаты лучше, особенно со вторым и третьим изображениями, при одинаковых параметрах обнаружения линий.
# >
# >Преимуществом подхода scikit-image является возможность анализа матрицы аккумулятора и более гибкая настройка поиска пиков, что полезно для исследовательских задач.
# >
# >Оба подхода показали хорошую эффективность в обнаружении линий. Вероятностное преобразование Хафа оказалось более практичным для реальных задач, так как возвращает отрезки линий, а не бесконечные прямые. Основными параметрами, влияющими на качество, являются порог голосования (threshold), минимальная длина линии и максимальный разрыв между сегментами.
# >
#
# *Задание 2.1*
# > В этом задании было реализовано преобразование Хафа для окружностей с помощью библиотеки OpenCV. С помощью реализованного алгоритма удалось обнаружить окружности на 3 изображениях.
# >
# >На 1 изображении находится автомобиль, результатом работы алгоритма стало обнаружение колёс целиком, отдельно дисков, а также алгоритм обнаружил буквы круглой формы на водяном знаке по центру изображения.
# >
# > На 2 изображении мишени. Алгоритм нашёл каждую из них, а для нескольких левых, которые стоят наиболее прямо к камере, также обнаружил внутренний круг.
# >
# > На 3 изображении приборная панель самолёта, на которой расположены круглые приборы. Алгоритм обнаружил все приборы на передней панели, а также показал другие элементы кабины, которые имеют круглую форму (кнопки, рычаги и т.д.).
# >
# > Алгоритм отработал достаточно хорошо. На примере двух последних изображений можно увидеть практическую ценность алгоритма в поиске круглых мишеней и приборов в кабине самолёта для дальнейшего получения с них информации.
#
# *Задание 2.2*
# > В этом задании было реализовано то же самое преобразование, только с помощью библиотеки scikit-image. Были обработаны те же изображения, что и в прошлом задании.
# >
# > На изображении 1 не удалось обнаружить оба колеса, были указаны несуществующие окружности.
# >
# > На изображении 2 помимо мишеней алгоритм нарисовал окружности около луков.
# >
# > На изображении 3 приборы были обнаружены чётко, но при этом было найдено меньше круглых объектов.
# >
# > В этом задании алгоритм отработал хуже, а также было потрачено больше времени на подбор аргументов функций. Если для алгоритма из предыдущего задания удалось подобрать аргументы, подошедшие ко всем изображениям, то во втором случае для первых двух картинок не удалось подобрать аргументы для высокой точности определения.
#
# *Задание 3*
# > Был реализован классический алгоритм преобразования Хафа для линий. На всех трёх изображениях он отработал чётко, но обнаруживал одни и те же и близко расположенные друг к другу линии, как на картинке 1 с широкими линиями судоку и как на картинке 3 с левой стороной двери, где видно, что обнаруженные линии расходятся к концам изображения.
#
# *Таким образом OpenCV предпочтительнее для промышленных приложений благодаря оптимизации и простоте использования. scikit-image лучше подходит для исследовательских задач, где важна прозрачность алгоритма и доступ к промежуточным данным. Качество результатов всех методов сильно зависит от качества выделения границ. Неправильно подобранные пороги могут привести как к пропуску объектов, так и к большому количеству ложных срабатываний.*
#
# *А само преобразование Хафа — это мощный и гибкий инструмент для детекции геометрических примитивов. Выбор конкретной реализации должен основываться на требованиях задачи: скорость, точность, интерпретируемость или интеграция с существующим пайплайном обработки изображений.*
